# %%
# Collecting staff data

experience = float(input("Enter years of work experience: "))
age = int(input("Enter staff age: "))

# Applying the tax logic
if
    # experience > 25 and age >= 55:
atr = 5600000

elif:
     # experience > 20 and age >= 45:
atr = 4480000

elif: 
     # experience > 10 and age >= 35:
atr = 1500000

    
else:
        # This covers staff < 10 years of experience AND below 35 years of age
        atr = 550000

# Displaying the result with currency formatting
print("-" * 30)
print(f"Annual Tax Revenue (ATR): N{atr:,}")
print("-" * 30)

print("Invalid input. Please enter numbers for age and experience.")
# Out:
#   Cell In[4], line 7
#     if
#       ^
# SyntaxError: invalid syntax
