# %% [markdown]
# ![Flowchart](p.png)

# %% [markdown]
# Begin
# Input("Cashier package the bag")
# Input("Collect receipt")
# Print("Checks if receipt is valid")
# Input("Exit the store")

# %% [markdown]
# ![Flowchart](m.png)

# %%
Begin
Input the names as name_1 and name_2
Input the age as age_1 and age_2
Display temp as age_1
Display age_1 as age_2
Display age_2 as temp
Print name_1 and name_2 as new age for age_1 and age_2
