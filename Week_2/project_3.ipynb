# %%
import pandas as pd

# Preparing the data in dictionary format
data = {
    "Name": ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa",
             "Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"],
    
    "Age": [17, 16, 17, 18, 16, 18, 17, 20, 19, 17,
            19, 16, 18, 17, 20, 19, 16, 18, 17, 19],
    
    "Height": [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5,
               5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7],
    
    "Score": [80, 85, 70, 60, 76, 66, 87, 95, 50, 49,
              74, 87, 75, 68, 66, 78, 87, 98, 54, 60],
    
    "Gender": ["Girl"]*10 + ["Boy"]*10
}

# Creating the DataFrame
df = pd.DataFrame(data)

# Displaying the data in a tabular form
print("Student Data Table:")
print(df.to_string(index=False))
# Out:
# Student Data Table:
#    Name  Age  Height  Score Gender
#  Evelyn   17     5.5     80   Girl
# Jessica   16     6.0     85   Girl
#   Somto   17     5.4     70   Girl
#   Edith   18     5.9     60   Girl
#    Liza   16     5.6     76   Girl
# Madonna   18     5.5     66   Girl
#    Waje   17     6.1     87   Girl
#    Tola   20     6.0     95   Girl
#   Aisha   19     5.7     50   Girl
#  Latifa   17     5.5     49   Girl
# Chinedu   19     5.7     74    Boy
#    Liam   16     5.9     87    Boy
#    Wale   18     5.8     75    Boy
#  Gbenga   17     6.1     68    Boy
#  Abiola   20     5.9     66    Boy
#    Kola   19     5.5     78    Boy
#   Kunle   16     6.1     87    Boy
#  George   18     5.4     98    Boy
#  Thomas   17     5.8     54    Boy
#  Wesley   19     5.7     60    Boy

# %% [markdown]
# Begin
#
# Define the data for 10 girls (Names, Ages, Heights, Scores)
#
# Define the data for 10 boys (Names, Ages, Heights, Scores)
#
# Add the girls' and boys' data into a single list called "All Students."
#
# Print the table headers: "Name | Age | Height | Score."
#
# Input the data under each of its right headers
#
# End
