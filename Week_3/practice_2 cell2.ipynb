# %%
import tkinter as tk
from tkinter import messagebox
from PIL import image, ImageTk

def welcomeMessage(username):
    window = tk.Toplevel(root)   # create new window from root
    window.title("Admin Box")
    window.geometry("500x200")

    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()

    label_2 = tk.Label(window, text="This is Python GUI with Tkinter")
    label_2.pack()


def sumbit():
    username = username_entry.get()
    password = password_entry.get()

    if username == "Mary" and password == "cos 102":
        welcomeMessage(username)
    else:
        messagebox.showerror("login", "Invalid username or password")


root = tk.Tk()
root.title("Login")
root.geometry("300x200")

username_entry = tk.Entry(root)
username_entry.pack()

password_entry = tk.Entry(root, show="*")
password_entry.pack()

btn = tk.Button(root, text="Login", command=sumbit)
btn.pack()


root.mainloop()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[64], line 3
#       1 import tkinter as tk
#       2 from tkinter import messagebox
# ----> 3 from PIL import image, ImageTk
#       5 def welcomeMessage(username):
#       6     window = tk.Toplevel(root)   # create new window from root
#
# ImportError: cannot import name 'image' from 'PIL' (C:\Users\New\anaconda3\Lib\site-packages\PIL\__init__.py)
